# %%
import os
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score

#os.environ["CUDA_VISIBLE_DEVICES"] = "-1" #이것을 위로 두지 않으면 GPU 대신 CPU로 설정하는 게 동작하지 않음
# TensorFlow 로그 레벨 설정
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

# GPU 설정
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(f"Failed to set memory growth: {e}")
else:
    print("No GPU devices found. Running on CPU.")
# Out:
# No GPU devices found. Running on CPU.

# %%
# # 데이터 로드 함수
# def load_data(directory):
#     files_positive = []
#     files_negative = []

#     # 디렉토리 내 파일을 탐색
#     for file in os.listdir(directory):
#         if '_positive_' in file:
#             files_positive.append(os.path.join(directory, file))
#         elif '_negative_' in file:
#             files_negative.append(os.path.join(directory, file))

#     # 파일 로드
#     positive_data = [np.load(file) for file in files_positive]
#     negative_data = [np.load(file) for file in files_negative]

#     # 데이터와 레이블 결합
#     X = np.concatenate(positive_data + negative_data, axis=0)
#     y = np.array([1] * len(np.concatenate(positive_data)) + [0] * len(np.concatenate(negative_data)))

#     # 참여자 정보 생성 (파일 이름에서 참여자 ID 추출)
#     participants = []
#     for file in files_positive + files_negative:
#         participant_id = os.path.basename(file).split('_')[0]  # 파일 이름에서 참여자 ID 추출
#         participants.extend([participant_id] * np.load(file).shape[0])

#     participants = np.array(participants)

#     return X, y, participants

# %%
# def load_data(directory):
#     # Positive(긍정)과 Negative(부정) 데이터를 저장할 리스트 초기화
#     files_positive = []
#     files_negative = []

#     # 디렉토리에 있는 파일들을 탐색
#     for file in os.listdir(directory):
#         # 파일 이름에 '_positive_'가 포함되어 있으면 positive 파일 리스트에 추가
#         if '_positive_' in file:
#             files_positive.append(os.path.join(directory, file))
#         # 파일 이름에 '_negative_'가 포함되어 있으면 negative 파일 리스트에 추가
#         elif '_negative_' in file:
#             files_negative.append(os.path.join(directory, file))

#     # positive 또는 negative 파일이 하나도 없을 경우 예외를 발생시킴
#     if not files_positive or not files_negative:
#         raise ValueError(f"No files found. Positive: {files_positive}, Negative: {files_negative}")

#     # positive와 negative 파일의 데이터를 읽어서 각각 리스트에 저장
#     positive_data = [np.load(file) for file in files_positive]  # positive 파일 데이터 로드
#     negative_data = [np.load(file) for file in files_negative]  # negative 파일 데이터 로드

#     # positive와 negative 데이터를 합쳐서 X 데이터로 생성
#     # axis=0은 데이터를 샘플 축(행)으로 결합함
#     X = np.concatenate(positive_data + negative_data, axis=0)

#     # y 레이블 생성
#     # positive 데이터의 개수만큼 1로 된 레이블 생성 후
#     # negative 데이터의 개수만큼 0으로 된 레이블을 추가
#     y = np.array([1] * len(np.concatenate(positive_data)) + [0] * len(np.concatenate(negative_data)))

#     # 참여자 정보(participants) 생성
#     # 각 파일 이름에서 참여자 ID를 추출하고, 파일에 있는 데이터 개수만큼 반복
#     participants = []
#     for file in files_positive + files_negative:
#         # 파일 이름에서 참여자 ID 추출 (파일 이름은 예: "001_positive_data.npy")
#         participant_id = os.path.basename(file).split('_')[0]
#         # np.load(file).shape[0]: 해당 파일에 있는 샘플 개수
#         participants.extend([participant_id] * np.load(file).shape[0])

#     # participants 리스트를 NumPy 배열로 변환
#     participants = np.array(participants)

#     # 최종적으로 데이터(X), 레이블(y), 참여자 정보(participants)를 반환
#     return X, y, participants

# %%
def load_data(directory):
    """
    데이터를 로드하고, 레이블과 파일 이름을 포함하여 반환하는 함수

    Parameters:
        directory (str): 데이터가 저장된 디렉토리 경로

    Returns:
        X (np.ndarray): 입력 데이터
        y (np.ndarray): 레이블
        participants (np.ndarray): 참여자 정보
        file_names (np.ndarray): 각 샘플의 파일 이름
    """
    # Positive(긍정)과 Negative(부정) 데이터를 저장할 리스트 초기화
    files_positive = []
    files_negative = []

    # 디렉토리에 있는 파일들을 탐색
    for file in os.listdir(directory):
        # 파일 이름에 '_positive_'가 포함되어 있으면 positive 파일 리스트에 추가
        if '_positive_' in file:
            files_positive.append(os.path.join(directory, file))
        # 파일 이름에 '_negative_'가 포함되어 있으면 negative 파일 리스트에 추가
        elif '_negative_' in file:
            files_negative.append(os.path.join(directory, file))

    # positive 또는 negative 파일이 하나도 없을 경우 예외를 발생시킴
    if not files_positive or not files_negative:
        raise ValueError(f"No files found. Positive: {files_positive}, Negative: {files_negative}")

    # positive와 negative 파일의 데이터를 읽어서 각각 리스트에 저장
    positive_data = [np.load(file) for file in files_positive]  # positive 파일 데이터 로드
    negative_data = [np.load(file) for file in files_negative]  # negative 파일 데이터 로드

    # positive와 negative 데이터를 합쳐서 X 데이터로 생성
    # axis=0은 데이터를 샘플 축(행)으로 결합함
    X = np.concatenate(positive_data + negative_data, axis=0)

    # y 레이블 생성
    # positive 데이터의 개수만큼 1로 된 레이블 생성 후
    # negative 데이터의 개수만큼 0으로 된 레이블을 추가
    y = np.array([1] * len(np.concatenate(positive_data)) + [0] * len(np.concatenate(negative_data)))

    # 참여자 정보(participants) 및 파일 이름(file_names) 생성
    # 각 파일 이름에서 참여자 ID를 추출하고, 파일에 있는 데이터 개수만큼 반복
    participants = []
    file_names = []
    for file in files_positive + files_negative:
        # 파일 이름에서 참여자 ID 추출 (파일 이름 예: "001_positive_data.npy")
        participant_id = os.path.basename(file).split('_')[0]
        data = np.load(file)
        num_samples = data.shape[0]
        participants.extend([participant_id] * num_samples)
        file_names.extend([os.path.basename(file)] * num_samples)

    # 리스트를 NumPy 배열로 변환
    participants = np.array(participants)
    file_names = np.array(file_names)

    # 최종적으로 데이터(X), 레이블(y), 참여자 정보(participants), 파일 이름(file_names)를 반환
    return X, y, participants, file_names

# %%
# def create_cnn_model(input_shape, num_classes):
#     """
#     CNN 모델을 생성하고 컴파일하는 함수

#     Parameters:
#         input_shape (tuple): 입력 데이터의 형태 (예: (timesteps, features))
#         num_classes (int): 출력 클래스의 수 (예: 감정 레이블의 개수)

#     Returns:
#         model (Sequential): 생성된 CNN 모델
#     """
#     # Sequential 모델 생성
#     model = Sequential([
#         # 1D Convolutional Layer: 32개의 필터, kernel_size=3, 활성화 함수 ReLU
#         # input_shape 지정 (첫 번째 레이어에서만 필요)
#         Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),

#         # MaxPooling Layer: 풀링 크기(pool_size)=2, strides=1
#         # 특징 추출 후 차원을 줄여 모델의 복잡도를 감소시킴
#         MaxPooling1D(pool_size=2, strides=1),

#         # 1D Convolutional Layer: 64개의 필터, kernel_size=3, 활성화 함수 ReLU
#         Conv1D(64, kernel_size=3, activation='relu'),

#         # MaxPooling Layer: 풀링 크기(pool_size)=2, strides=1
#         MaxPooling1D(pool_size=2, strides=1),

#         # Flatten Layer: 1D 데이터를 1차원으로 펼침
#         # Fully Connected Layer에 입력으로 전달
#         Flatten(),

#         # Fully Connected Layer: 128개의 뉴런, 활성화 함수 ReLU
#         Dense(128, activation='relu'),

#         # Dropout Layer: 50%의 뉴런을 무작위로 비활성화 (overfitting 방지)
#         Dropout(0.5),

#         # Output Layer: 클래스 수에 따라 Softmax 활성화 함수 사용
#         # 클래스별 확률 분포 출력
#         Dense(num_classes, activation='softmax')
#     ])

#     # 모델 컴파일: 최적화 알고리즘, 손실 함수, 평가지표 설정
#     # optimizer: Adam, 손실 함수: categorical_crossentropy, 평가지표: accuracy
#     model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#     return model  # 생성된 모델 반환

# %%
def create_cnn_model(input_shape, num_classes):
    """
    CNN 모델을 생성하고 컴파일하는 함수

    Parameters:
        input_shape (tuple): 입력 데이터의 형태 (예: (timesteps, features))
        num_classes (int): 출력 클래스의 수 (예: 감정 레이블의 개수)

    Returns:
        model (Sequential): 생성된 CNN 모델
    """
    # Sequential 모델 생성
    model = Sequential([
        # 1D Convolutional Layer: 32개의 필터, kernel_size=3, 활성화 함수 ReLU
        # input_shape 지정 (첫 번째 레이어에서만 필요)
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),

        # MaxPooling Layer: 풀링 크기(pool_size)=2, strides=1
        # 특징 추출 후 차원을 줄여 모델의 복잡도를 감소시킴
        MaxPooling1D(pool_size=2, strides=1),

        # 1D Convolutional Layer: 64개의 필터, kernel_size=3, 활성화 함수 ReLU
        Conv1D(64, kernel_size=3, activation='relu'),

        # MaxPooling Layer: 풀링 크기(pool_size)=2, strides=1
        MaxPooling1D(pool_size=2, strides=1),

        # Flatten Layer: 1D 데이터를 1차원으로 펼침
        # Fully Connected Layer에 입력으로 전달
        Flatten(),

        # Fully Connected Layer: 128개의 뉴런, 활성화 함수 ReLU
        Dense(128, activation='relu'),

        # Dropout Layer: 50%의 뉴런을 무작위로 비활성화 (overfitting 방지)
        Dropout(0.5),

        # Output Layer: 클래스 수에 따라 Softmax 활성화 함수 사용
        # 클래스별 확률 분포 출력
        Dense(num_classes, activation='softmax')
    ])

    # 모델 컴파일: 최적화 알고리즘, 손실 함수, 평가지표 설정
    # optimizer: Adam, 손실 함수: categorical_crossentropy, 평가지표: accuracy
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model  # 생성된 모델 반환

# %%
# # 테스트 데이터 예측 함수
# def predict_test_samples():
#     directory = '/home/bcml1/2025_EMOTION/DEAP_EEG/ch_BPF'  # 데이터를 저장한 디렉토리 경로
#     #directory = '/home/bcml1/sigenv/eeg_cnn_model1'  # 데이터를 저장한 디렉토리 경로
#     X, y, participants = load_data(directory)

#     # 데이터 크기 확인
#     print(f"X shape: {X.shape}, y shape: {y.shape}, participants shape: {participants.shape}")

#     # participants 배열의 크기가 X와 y의 첫 번째 축과 일치하지 않는 경우 처리
#     if participants.shape[0] != X.shape[0] or participants.shape[0] != y.shape[0]:
#         raise ValueError("Mismatch in dimensions: 'participants', 'X', and 'y' must have the same number of samples.")

#     # 문자열 라벨을 숫자형 라벨로 매핑
#     unique_labels = np.unique(y)
#     label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
#     y_int = np.array([label_to_int[label] for label in y])

#     num_classes = len(unique_labels)
#     input_shape = X.shape[1:]  # 데이터가 올바르게 reshape되었다고 가정
#     y_categorical = to_categorical(y_int, num_classes=num_classes)

#     # Leave-One-Group-Out 방식으로 intra-session 검증
#     logo = LeaveOneGroupOut()
#     accuracy_scores = []

#     for train_index, test_index in logo.split(X, y_categorical, groups=participants):
#         X_train, X_test = X[train_index], X[test_index]
#         y_train, y_test = y_categorical[train_index], y_categorical[test_index]

#         # 모델 생성 및 학습
#         model = create_cnn_model(input_shape, num_classes)
#         history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

#         # 학습 과정 확인
#         print("Training history:")
#         print("Accuracy:", history.history['accuracy'])
#         print("Loss:", history.history['loss'])

#         # 모델 평가
#         test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
#         accuracy_scores.append(test_accuracy)

#         print(f"Test session accuracy: {test_accuracy:.4f}")

#     print(f"Mean accuracy across sessions: {np.mean(accuracy_scores):.4f}")

# # 텍스트로 저장하는 코드 구현
# if __name__ == "__main__":
#     predict_test_samples()

# %%
# 만든 모델을 저장하고 테스트를 분리하여 실행하는 코드를 작성

# %%
# 테스트 데이터 예측 함수
def predict_test_samples():
    """
    모델을 학습하고 평가한 후, 결과를 텍스트 파일로 저장하는 함수
    """
    directory = '/home/bcml1/2025_EMOTION/DEAP_EEG/ch_BPF'  # 데이터를 저장한 디렉토리 경로
    #directory = '/home/bcml1/sigenv/eeg_cnn_model1'  # 데이터를 저장한 디렉토리 경로
    X, y, participants, file_names = load_data(directory)
    
    # 데이터 크기 확인
    print(f"X shape: {X.shape}, y shape: {y.shape}, participants shape: {participants.shape}, file_names shape: {file_names.shape}")

    # participants 배열의 고유 그룹 수 확인
    unique_groups = np.unique(participants)
    num_groups = len(unique_groups)
    print(f"Number of unique groups (participants): {num_groups}")
    print(f"Unique groups: {unique_groups}")

    # 교차 검증 폴드 수 확인
    if num_groups < 2:
        raise ValueError("교차 검증을 수행하기 위해서는 최소 2개의 고유한 그룹(참여자)이 필요합니다.")
          
    # participants 배열의 크기가 X와 y의 첫 번째 축과 일치하지 않는 경우 처리
    if participants.shape[0] != X.shape[0] or participants.shape[0] != y.shape[0] or file_names.shape[0] != X.shape[0]:
        raise ValueError("Mismatch in dimensions: 'participants', 'X', 'y', and 'file_names' must have the same number of samples.")

    # 문자열 라벨을 숫자형 라벨로 매핑
    unique_labels = np.unique(y)
    label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
    y_int = np.array([label_to_int[label] for label in y])

    num_classes = len(unique_labels)
    input_shape = X.shape[1:]  # 데이터가 올바르게 reshape되었다고 가정
    y_categorical = to_categorical(y_int, num_classes=num_classes)

    # Leave-One-Group-Out 방식으로 intra-session 검증
    logo = LeaveOneGroupOut()
    accuracy_scores = []

    # 전체 예측 결과 저장을 위한 리스트 초기화
    all_true = []
    all_pred = []
    all_file_names = []
    
    for fold, (train_index, test_index) in enumerate(logo.split(X, y_categorical, groups=participants), 1):
        print(f"\nFold {fold}:")
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y_categorical[train_index], y_categorical[test_index]
        file_names_test = file_names[test_index]
        
        # 모델 생성 및 학습
        model = create_cnn_model(input_shape, num_classes)
        history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

        # 학습 과정 확인
        print("Training history:")
        print("Accuracy:", history.history['accuracy'])
        print("Loss:", history.history['loss'])

        # 모델 예측
        y_pred_prob = model.predict(X_test)
        y_pred = np.argmax(y_pred_prob, axis=1)
        y_true = np.argmax(y_test, axis=1)
        
        # 정확도 계산
        test_accuracy = accuracy_score(y_true, y_pred)
        accuracy_scores.append(test_accuracy)

        print(f"Test session accuracy: {test_accuracy:.4f}")

         # 전체 예측 결과 저장
        all_true.extend(y_true)
        all_pred.extend(y_pred)
        all_file_names.extend(file_names_test)

    # 전체 정확도 및 분류 보고서 계산
    final_accuracy = accuracy_score(all_true, all_pred)
    classification_rep = classification_report(all_true, all_pred, target_names=['negative', 'positive'], digits=4)

    # Prediction Details (file-level) 생성
    prediction_details = []
    for file, true, pred in zip(all_file_names, all_true, all_pred):
        correctness = "Correct" if true == pred else "Incorrect"
        prediction_details.append(f"{file}: Predicted={pred}, Actual={true} ({correctness})")

    # 결과를 텍스트 파일로 저장
    output_file = "cnn_model_intra_evaluation_results.txt"
    with open(output_file, 'w') as f:
        f.write("Multimodal Model Evaluation Results\n")
        f.write(f"Final Accuracy: {final_accuracy:.4f}\n\n")

        f.write("Detailed Classification Report (Final):\n")
        f.write(classification_rep + "\n")

        f.write("Prediction Details (file-level):\n")
        for detail in prediction_details:
            f.write(detail + "\n")

    print(f"Mean accuracy across sessions: {np.mean(accuracy_scores):.4f}")
    
    print(f"\nEvaluation results have been saved to '{output_file}'.")

# 텍스트로 저장하는 코드 구현
if __name__ == "__main__":
    predict_test_samples()
# Out:
# X shape: (322, 8, 5120), y shape: (322,), participants shape: (322,), file_names shape: (322,)
# Number of unique groups (participants): 10
# Unique groups: ['s01' 's02' 's04' 's07' 's11' 's14' 's19' 's25' 's28' 's29']
#
# Fold 1:
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5095 - loss: 1613.6124
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5139 - loss: 1977.5764
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5755 - loss: 1528.4154
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5127 - loss: 1566.7070
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5113 - loss: 1411.1475
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5574 - loss: 844.6661
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5803 - loss: 1124.4108
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5591 - loss: 453.2572
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5349 - loss: 616.9150
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5536 - loss: 519.2900
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5254 - loss: 668.1924
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6036 - loss: 612.9097
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6537 - loss: 459.7314
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6307 - loss: 154.7930
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6471 - loss: 265.5175
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6678 - loss: 244.6998
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6823 - loss: 233.9649
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6272 - loss: 166.4142
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6597 - loss: 193.6766
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6686 - loss: 76.4683
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6215 - loss: 106.4606
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6523 - loss: 72.7467
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6289 - loss: 64.6721
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6471 - loss: 140.3339
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6736 - loss: 29.3175
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7031 - loss: 140.6062
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6556 - loss: 73.9037
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7019 - loss: 63.7430
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6980 - loss: 36.5072
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6860 - loss: 135.6760
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7124 - loss: 42.4613
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6597 - loss: 93.7971
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6649 - loss: 54.3379
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6320 - loss: 23.8473
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6849 - loss: 32.6489
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6553 - loss: 39.9530
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6332 - loss: 40.5124
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6611 - loss: 56.5982
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5920 - loss: 22.0870
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6563 - loss: 57.9005
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5870 - loss: 105.5569
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6420 - loss: 49.4245
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6496 - loss: 49.9452
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6422 - loss: 44.0673
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6814 - loss: 51.2106
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6157 - loss: 19.9140
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5961 - loss: 134.3421
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6186 - loss: 120.7980
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5746 - loss: 163.5871
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5797 - loss: 22.8591
# Training history:
# Accuracy: [0.47349822521209717, 0.5053003430366516, 0.5583038926124573, 0.5441696047782898, 0.5229681730270386, 0.565371036529541, 0.565371036529541, 0.565371036529541, 0.565371036529541, 0.5689045786857605, 0.5441696047782898, 0.5936395525932312, 0.6431095600128174, 0.6183745861053467, 0.6501767039299011, 0.6431095600128174, 0.6713780760765076, 0.6289752721786499, 0.6254416704177856, 0.6325088143348694, 0.6219081282615662, 0.6678445339202881, 0.6466431021690369, 0.6501767039299011, 0.685512363910675, 0.6713780760765076, 0.6360424160957336, 0.6996466517448425, 0.6890459656715393, 0.71378093957901, 0.6678445339202881, 0.6537102460861206, 0.6501767039299011, 0.6431095600128174, 0.6607773900032043, 0.6607773900032043, 0.6643109321594238, 0.6395759582519531, 0.6219081282615662, 0.6572437882423401, 0.6219081282615662, 0.6537102460861206, 0.6254416704177856, 0.6749116778373718, 0.6607773900032043, 0.6431095600128174, 0.6007066965103149, 0.6219081282615662, 0.5795053243637085, 0.5901060104370117]
# Loss: [2298.085205078125, 2107.72216796875, 1458.0311279296875, 1431.3115234375, 1221.11669921875, 800.718505859375, 1444.196044921875, 477.0461120605469, 441.3100280761719, 669.257080078125, 733.39306640625, 599.1832885742188, 307.0789489746094, 188.06434631347656, 356.8984680175781, 307.7183532714844, 256.1046142578125, 138.8279571533203, 240.75587463378906, 106.0292739868164, 147.86863708496094, 56.410072326660156, 77.82843017578125, 81.82289123535156, 28.574647903442383, 115.6124496459961, 79.785888671875, 51.400699615478516, 38.0214729309082, 100.4054946899414, 69.66036987304688, 62.62604904174805, 58.62258529663086, 26.867053985595703, 40.007389068603516, 44.95075607299805, 36.86640930175781, 57.25706100463867, 18.62303352355957, 139.84317016601562, 83.71385192871094, 45.550437927246094, 80.37389373779297, 31.064334869384766, 78.71459197998047, 18.334518432617188, 132.75839233398438, 98.52540588378906, 125.62933349609375, 36.491188049316406]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test session accuracy: 0.6667
#
# Fold 2:
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5217 - loss: 2539.4187
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5644 - loss: 3643.1716
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5582 - loss: 2589.0942
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5732 - loss: 2433.6414
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5637 - loss: 1624.0082
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5194 - loss: 2317.2605
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5175 - loss: 1373.4729
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5059 - loss: 1743.7770
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5752 - loss: 1358.9788
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5761 - loss: 1111.8827
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5967 - loss: 1525.4701
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5578 - loss: 1005.1806
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6080 - loss: 532.2162
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5541 - loss: 501.0827
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5396 - loss: 1101.1216
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6330 - loss: 544.4689
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6061 - loss: 827.6413
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5915 - loss: 488.0336
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6219 - loss: 313.5846
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5648 - loss: 349.0000
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5624 - loss: 254.2040
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5451 - loss: 766.9309
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5445 - loss: 1366.7679
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5925 - loss: 876.0433
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5287 - loss: 513.4285
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5327 - loss: 571.5490
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6071 - loss: 460.0696
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5937 - loss: 461.2495
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6003 - loss: 258.2015
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6121 - loss: 518.9381
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5697 - loss: 590.6222
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5693 - loss: 874.2151
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5419 - loss: 558.0737
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5513 - loss: 249.8556
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6486 - loss: 86.1179
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6619 - loss: 249.7099
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6811 - loss: 201.8752
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6486 - loss: 204.8368
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6467 - loss: 114.7446
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6371 - loss: 123.7725
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5823 - loss: 73.7446
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6308 - loss: 44.7480
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6494 - loss: 39.3043
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6019 - loss: 45.9321
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5973 - loss: 71.1316
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5766 - loss: 81.5279
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6279 - loss: 52.8678
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6824 - loss: 13.7914
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6112 - loss: 14.6031
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6316 - loss: 46.2682
# Training history:
# Accuracy: [0.5275862216949463, 0.5379310250282288, 0.5724138021469116, 0.5758620500564575, 0.565517246723175, 0.5379310250282288, 0.5275862216949463, 0.5137931108474731, 0.5862069129943848, 0.5827586054801941, 0.5620689392089844, 0.548275887966156, 0.5758620500564575, 0.5620689392089844, 0.5586206912994385, 0.6275861859321594, 0.6034482717514038, 0.5793103575706482, 0.6586207151412964, 0.568965494632721, 0.5827586054801941, 0.5275862216949463, 0.5551724433898926, 0.5862069129943848, 0.5448275804519653, 0.5379310250282288, 0.6206896305084229, 0.5931034684181213, 0.5827586054801941, 0.5931034684181213, 0.5862069129943848, 0.5724138021469116, 0.5586206912994385, 0.5896551609039307, 0.6482758522033691, 0.6793103218078613, 0.6896551847457886, 0.6413792967796326, 0.634482741355896, 0.6206896305084229, 0.6000000238418579, 0.6620689630508423, 0.6517241597175598, 0.6103448271751404, 0.6103448271751404, 0.5827586054801941, 0.6275861859321594, 0.6551724076271057, 0.6241379380226135, 0.6482758522033691]
# Loss: [3336.3037109375, 3857.859375, 3473.96533203125, 2796.740966796875, 1540.9786376953125, 2363.257080078125, 1439.1318359375, 2376.679931640625, 1436.8345947265625, 1135.4425048828125, 1414.832275390625, 1044.353759765625, 711.6278076171875, 605.5030517578125, 731.297119140625, 598.148681640625, 542.562744140625, 566.4638061523438, 284.3435363769531, 318.4762878417969, 290.5197448730469, 1403.6390380859375, 1295.0252685546875, 872.2161865234375, 602.4437255859375, 599.9766235351562, 547.9855346679688, 644.1978759765625, 404.3209533691406, 604.021484375, 514.8174438476562, 620.4937744140625, 686.9805908203125, 384.9089660644531, 155.51129150390625, 275.1734924316406, 302.9880065917969, 223.35914611816406, 90.11417388916016, 209.06578063964844, 94.49828338623047, 26.43584442138672, 38.844947814941406, 48.333099365234375, 54.94532012939453, 74.61170196533203, 62.276527404785156, 20.764421463012695, 19.464786529541016, 56.72816467285156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Test session accuracy: 0.5938
#
# Fold 3:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4967 - loss: 2774.7673
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5772 - loss: 3467.4333
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5330 - loss: 2677.8948
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5585 - loss: 3580.7786
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5882 - loss: 2004.9961
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5526 - loss: 1489.2429
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5557 - loss: 1182.2926
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5690 - loss: 728.2799
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5739 - loss: 825.1627
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5472 - loss: 691.1527
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5709 - loss: 473.1697
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5357 - loss: 742.9011
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5887 - loss: 541.6609
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6219 - loss: 640.0420
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6354 - loss: 529.5447
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5998 - loss: 386.4742
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6089 - loss: 521.7557
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5699 - loss: 256.2093
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5829 - loss: 894.9479
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6473 - loss: 635.2936
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6290 - loss: 1041.0560
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 442ms/step - accuracy: 0.5717 - loss: 701.0155
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5694 - loss: 501.8598
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6290 - loss: 436.5659
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6116 - loss: 349.8773
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6413 - loss: 167.3970
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6036 - loss: 361.4864
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6153 - loss: 247.9589
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6195 - loss: 73.3783
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5988 - loss: 124.3282
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6557 - loss: 186.2101
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6901 - loss: 52.3658
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6433 - loss: 79.8978
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6281 - loss: 58.8715
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6477 - loss: 45.2107
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6494 - loss: 65.7953
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6984 - loss: 42.3392
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5844 - loss: 19.9189
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6273 - loss: 10.3196
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6487 - loss: 6.4150
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6616 - loss: 8.8575
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6016 - loss: 13.4057
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6129 - loss: 23.7207
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6024 - loss: 5.6335
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6015 - loss: 10.2700
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5622 - loss: 13.5435
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6479 - loss: 3.5385
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6431 - loss: 40.1953
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6116 - loss: 88.1693
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6134 - loss: 406.0610
# Training history:
# Accuracy: [0.47750866413116455, 0.5813148617744446, 0.5363321900367737, 0.5605536103248596, 0.5813148617744446, 0.5432525873184204, 0.5778546929359436, 0.5605536103248596, 0.5778546929359436, 0.5432525873184204, 0.5986159443855286, 0.5432525873184204, 0.5916954874992371, 0.6159169673919678, 0.633217990398407, 0.5951557159423828, 0.6055363416671753, 0.6055363416671753, 0.5847750902175903, 0.612456738948822, 0.6262975931167603, 0.5709342360496521, 0.5743944644927979, 0.612456738948822, 0.5951557159423828, 0.6366782188415527, 0.6193771362304688, 0.5882353186607361, 0.5986159443855286, 0.5916954874992371, 0.6574394702911377, 0.6747404932975769, 0.6297577619552612, 0.6366782188415527, 0.6366782188415527, 0.6678200960159302, 0.6989619135856628, 0.6159169673919678, 0.6297577619552612, 0.6435986161231995, 0.6574394702911377, 0.6020761132240295, 0.6089965105056763, 0.6020761132240295, 0.6159169673919678, 0.5813148617744446, 0.633217990398407, 0.6193771362304688, 0.633217990398407, 0.5847750902175903]
# Loss: [4111.87451171875, 3755.927734375, 3415.16259765625, 3302.956787109375, 2547.703369140625, 1669.238525390625, 1669.4713134765625, 725.5189819335938, 1141.8480224609375, 628.7548828125, 620.60400390625, 1007.6432495117188, 533.4329833984375, 673.156982421875, 576.8916015625, 421.1657409667969, 374.5067443847656, 274.0529479980469, 740.55126953125, 775.9780883789062, 596.297119140625, 642.1650390625, 402.1633605957031, 362.5230407714844, 248.50167846679688, 266.6492004394531, 223.78419494628906, 277.9154357910156, 126.54486083984375, 202.28187561035156, 182.94760131835938, 71.58638763427734, 76.39625549316406, 45.386383056640625, 35.32473373413086, 46.69826889038086, 53.38524627685547, 21.84091567993164, 15.695792198181152, 8.183755874633789, 12.111834526062012, 14.304875373840332, 22.2683048248291, 9.092656135559082, 7.080198287963867, 11.191083908081055, 3.617485761642456, 115.68291473388672, 117.43441772460938, 472.56109619140625]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Test session accuracy: 0.4242
#
# Fold 4:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5803 - loss: 1465.1887
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4996 - loss: 5606.5195
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5892 - loss: 3733.1260
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5629 - loss: 3049.4641
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5502 - loss: 2271.5581
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6123 - loss: 1299.3279
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6047 - loss: 1424.0428
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5027 - loss: 1829.0909
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5737 - loss: 1530.8157
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5696 - loss: 912.5156
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5785 - loss: 864.4561
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6108 - loss: 1092.8547
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6266 - loss: 1854.3759
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6372 - loss: 836.5176
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6227 - loss: 737.7584
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6785 - loss: 292.8891
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6598 - loss: 297.0851
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6573 - loss: 303.6342
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6025 - loss: 760.2822
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6664 - loss: 493.1629
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6950 - loss: 828.3808
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6112 - loss: 261.8215
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5856 - loss: 1207.6938
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5835 - loss: 2750.0613
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6016 - loss: 3360.4377
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6174 - loss: 714.9859
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6119 - loss: 781.8527
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6008 - loss: 1179.9645
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6387 - loss: 302.6182
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6345 - loss: 232.3901
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6505 - loss: 273.3069
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6513 - loss: 233.7218
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6150 - loss: 340.8352
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6739 - loss: 182.8685
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6604 - loss: 432.4460
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5476 - loss: 242.2499
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5355 - loss: 340.9785
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5202 - loss: 337.2025
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5388 - loss: 193.2417
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5068 - loss: 83.9129
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5172 - loss: 109.8952
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5232 - loss: 30.0789
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5637 - loss: 108.1047
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.5712 - loss: 24.7344
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5754 - loss: 56.5418
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5328 - loss: 16.6536
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6023 - loss: 19.2981
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5637 - loss: 20.7249
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5714 - loss: 79.1582
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 241ms/step - accuracy: 0.6234 - loss: 11.8903
# Training history:
# Accuracy: [0.5841924548149109, 0.49484536051750183, 0.5670102834701538, 0.5498281717300415, 0.5601374506950378, 0.5876288414001465, 0.6116838455200195, 0.5051546096801758, 0.5704467296600342, 0.5704467296600342, 0.5945017337799072, 0.6116838455200195, 0.6254295706748962, 0.6323024034500122, 0.6323024034500122, 0.6563574075698853, 0.6563574075698853, 0.6357388496398926, 0.5979381203651428, 0.6391752362251282, 0.7010309100151062, 0.6494845151901245, 0.5601374506950378, 0.5910652875900269, 0.6048110127449036, 0.6048110127449036, 0.6048110127449036, 0.5841924548149109, 0.6254295706748962, 0.6185566782951355, 0.6254295706748962, 0.6219931244850159, 0.6254295706748962, 0.6529209613800049, 0.6426116824150085, 0.5601374506950378, 0.5257731676101685, 0.5120275020599365, 0.5223367810249329, 0.5051546096801758, 0.5292096138000488, 0.5463917255401611, 0.5738831758499146, 0.5876288414001465, 0.5773195624351501, 0.5601374506950378, 0.5807560086250305, 0.5670102834701538, 0.5532646179199219, 0.6048110127449036]
# Loss: [1844.81201171875, 4949.29443359375, 3925.438232421875, 2429.344482421875, 2450.335205078125, 1453.4173583984375, 1287.5755615234375, 1899.1397705078125, 1539.6004638671875, 1019.592041015625, 735.427734375, 1163.190673828125, 1116.41796875, 877.7471923828125, 737.9749755859375, 370.12359619140625, 292.72735595703125, 447.8788146972656, 891.1915893554688, 726.2201538085938, 628.25830078125, 333.5596618652344, 1524.224853515625, 2717.24072265625, 2910.287353515625, 778.5936889648438, 1031.1103515625, 632.4680786132812, 339.83648681640625, 388.02587890625, 276.053466796875, 247.6519775390625, 441.2593078613281, 388.329345703125, 224.2642364501953, 281.0254211425781, 349.8706970214844, 310.6387023925781, 159.41110229492188, 105.01507568359375, 187.30418395996094, 33.97478485107422, 91.96839141845703, 30.78680992126465, 44.38621520996094, 15.940509796142578, 26.01835823059082, 24.85198402404785, 50.2352180480957, 19.211069107055664]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Test session accuracy: 0.3871
#
# Fold 5:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4843 - loss: 2097.6201
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5436 - loss: 3729.1445
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5669 - loss: 1915.7941
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5371 - loss: 4035.9480
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5257 - loss: 1861.1920
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5834 - loss: 1245.5724
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5711 - loss: 4128.3018
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5218 - loss: 1582.7529
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5847 - loss: 1726.8136
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5739 - loss: 951.9411
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5848 - loss: 1536.0946
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6080 - loss: 682.7567
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6352 - loss: 797.7811
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5672 - loss: 1435.7217
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5674 - loss: 1567.2004
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - accuracy: 0.5604 - loss: 468.4986
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5869 - loss: 791.4960
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5840 - loss: 830.8160
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6071 - loss: 459.9810
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6123 - loss: 330.0066
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5670 - loss: 855.5468
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6482 - loss: 265.0693
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6644 - loss: 257.8367
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6555 - loss: 155.1191
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6636 - loss: 176.4994
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6476 - loss: 138.1649
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6698 - loss: 129.7926
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7321 - loss: 87.0058
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6851 - loss: 105.4465
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6770 - loss: 99.5781
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7169 - loss: 62.4218
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7543 - loss: 75.8880
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7288 - loss: 49.4528
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7055 - loss: 54.7636
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6382 - loss: 73.3357
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6515 - loss: 98.6337
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7208 - loss: 73.4712
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7468 - loss: 132.2096
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7114 - loss: 41.1800
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6647 - loss: 62.3366
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6669 - loss: 40.9685
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6813 - loss: 36.6281
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6611 - loss: 34.0356
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6665 - loss: 111.5588
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6523 - loss: 94.1256
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6956 - loss: 49.6162
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6534 - loss: 136.6659
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6473 - loss: 39.3636
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7081 - loss: 170.8051
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6186 - loss: 103.5585
# Training history:
# Accuracy: [0.4794520437717438, 0.5308219194412231, 0.551369845867157, 0.5547945499420166, 0.5479452013969421, 0.5650684833526611, 0.585616409778595, 0.5068492889404297, 0.5650684833526611, 0.5719178318977356, 0.5890411138534546, 0.5821917653083801, 0.6335616707801819, 0.5445205569267273, 0.568493127822876, 0.5582191944122314, 0.5719178318977356, 0.5890411138534546, 0.6061643958091736, 0.5993150472640991, 0.5924657583236694, 0.6301369667053223, 0.6712328791618347, 0.6335616707801819, 0.6678082346916199, 0.6164383292198181, 0.664383590221405, 0.7226027250289917, 0.6609588861465454, 0.664383590221405, 0.7226027250289917, 0.7397260069847107, 0.7054794430732727, 0.6849315166473389, 0.6575342416763306, 0.6678082346916199, 0.7294520735740662, 0.7123287916183472, 0.7089040875434875, 0.6952054500579834, 0.6952054500579834, 0.6952054500579834, 0.6917808055877686, 0.6506849527359009, 0.6678082346916199, 0.7226027250289917, 0.6472602486610413, 0.6575342416763306, 0.6678082346916199, 0.6506849527359009]
# Loss: [3140.10546875, 3202.516357421875, 2622.3369140625, 3072.14013671875, 2077.61083984375, 1344.55859375, 2965.029296875, 1914.7095947265625, 2053.918701171875, 1195.533447265625, 1442.927490234375, 663.692138671875, 1048.3814697265625, 1941.5543212890625, 1498.40380859375, 479.6022644042969, 814.9659423828125, 724.789794921875, 539.5821533203125, 433.92510986328125, 898.8270263671875, 312.8697509765625, 291.494873046875, 206.31231689453125, 192.4249267578125, 187.73643493652344, 187.1082000732422, 98.75162506103516, 83.3576431274414, 131.14968872070312, 83.84172821044922, 109.90763092041016, 67.60291290283203, 73.89999389648438, 79.24748992919922, 124.8910140991211, 57.8868522644043, 155.51873779296875, 45.134254455566406, 79.16940307617188, 52.647823333740234, 35.81627655029297, 37.88492965698242, 94.90052795410156, 69.99725341796875, 49.71521759033203, 203.12384033203125, 58.715049743652344, 119.1156997680664, 92.59550476074219]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Test session accuracy: 0.5667
#
# Fold 6:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5095 - loss: 1739.3927
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.5074 - loss: 5340.0000
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5295 - loss: 3066.7737
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5689 - loss: 2797.1746
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.5776 - loss: 3020.0742
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5290 - loss: 3060.2332
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5051 - loss: 5475.3413
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5065 - loss: 3321.4465
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5931 - loss: 1368.8547
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6181 - loss: 1414.8787
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5454 - loss: 624.7189
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6280 - loss: 1173.1821
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5659 - loss: 958.7632
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6207 - loss: 801.4627
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5384 - loss: 1211.3362
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5840 - loss: 646.0770
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5799 - loss: 324.3043
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6268 - loss: 322.0277
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6339 - loss: 357.8436
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6279 - loss: 322.0736
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6316 - loss: 422.8105
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6562 - loss: 611.5132
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6210 - loss: 490.3838
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5549 - loss: 665.9018
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6359 - loss: 450.2272
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6590 - loss: 871.3889
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6290 - loss: 542.9462
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6619 - loss: 320.5537
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6435 - loss: 404.4904
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7006 - loss: 302.6219
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5985 - loss: 273.2504
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6650 - loss: 134.0366
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7044 - loss: 323.7004
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6831 - loss: 246.2589
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6981 - loss: 379.3470
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6841 - loss: 609.4929
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5819 - loss: 727.6091
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6701 - loss: 211.2661
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7364 - loss: 205.2440
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7401 - loss: 114.4266
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7267 - loss: 171.3093
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6887 - loss: 234.8469
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7505 - loss: 95.5565
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6528 - loss: 836.1611
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7375 - loss: 160.2651
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6469 - loss: 154.8541
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7146 - loss: 115.5463
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7292 - loss: 276.6211
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7217 - loss: 226.5007
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7401 - loss: 43.4948
# Training history:
# Accuracy: [0.49140894412994385, 0.5017182230949402, 0.5326460599899292, 0.5532646179199219, 0.5670102834701538, 0.5085910558700562, 0.5085910558700562, 0.5223367810249329, 0.5807560086250305, 0.5635738968849182, 0.5498281717300415, 0.5979381203651428, 0.5567010045051575, 0.6048110127449036, 0.5532646179199219, 0.5532646179199219, 0.5876288414001465, 0.6254295706748962, 0.6391752362251282, 0.6288659572601318, 0.6323024034500122, 0.6666666865348816, 0.6288659572601318, 0.5910652875900269, 0.6219931244850159, 0.6219931244850159, 0.6082473993301392, 0.6288659572601318, 0.6426116824150085, 0.6769759654998779, 0.6563574075698853, 0.6460481286048889, 0.7044673562049866, 0.6666666865348816, 0.6838487982749939, 0.6872852444648743, 0.5601374506950378, 0.6872852444648743, 0.7353951930999756, 0.7216494679450989, 0.7250859141349792, 0.6941580772399902, 0.7422680258750916, 0.6735395193099976, 0.7285223603248596, 0.6460481286048889, 0.7147766351699829, 0.7319587469100952, 0.7079038023948669, 0.7560137510299683]
# Loss: [2487.575927734375, 4835.623046875, 3209.48291015625, 3818.013671875, 3310.965087890625, 2807.544921875, 4280.935546875, 3299.1279296875, 1723.6781005859375, 1662.220458984375, 719.78369140625, 1344.89794921875, 1118.65771484375, 807.3734741210938, 1082.2274169921875, 595.8855590820312, 393.5530090332031, 346.67431640625, 376.41778564453125, 505.273681640625, 631.48486328125, 412.6087341308594, 462.11376953125, 587.554443359375, 594.1725463867188, 734.415283203125, 446.6578674316406, 306.960205078125, 421.4718933105469, 507.28564453125, 207.42555236816406, 127.89666748046875, 845.823974609375, 380.4134826660156, 613.7886352539062, 430.7577819824219, 854.6725463867188, 193.5018310546875, 296.24609375, 93.24835205078125, 173.33499145507812, 267.4686584472656, 123.84127807617188, 537.69091796875, 255.5581817626953, 114.27056121826172, 139.69212341308594, 202.0519256591797, 201.41830444335938, 38.585960388183594]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Test session accuracy: 0.5806
#
# Fold 7:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4275 - loss: 2165.2590
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5326 - loss: 2586.2251
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4950 - loss: 1678.4240
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6197 - loss: 1170.3752
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5790 - loss: 1381.1412
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6391 - loss: 853.6229
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5542 - loss: 1075.2645
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5510 - loss: 1069.4761
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5490 - loss: 1636.6323
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5493 - loss: 1226.2368
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5567 - loss: 1030.6056
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6032 - loss: 1219.6135
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6658 - loss: 737.7936
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6121 - loss: 1027.1331
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6598 - loss: 729.2773
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6721 - loss: 577.3689
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6530 - loss: 359.8921
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7059 - loss: 747.3932
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6695 - loss: 257.0436
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6422 - loss: 340.3481
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7001 - loss: 625.9100
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6369 - loss: 814.4478
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7219 - loss: 534.5424
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6397 - loss: 366.6736
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6862 - loss: 178.3560
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7348 - loss: 170.8370
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7209 - loss: 137.2297
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7186 - loss: 147.5092
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7447 - loss: 110.9340
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7142 - loss: 202.5463
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7649 - loss: 60.9253
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7165 - loss: 64.3358
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7597 - loss: 70.6819
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7244 - loss: 117.3722
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7118 - loss: 139.0724
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7100 - loss: 170.6685
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7506 - loss: 108.4546
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7710 - loss: 58.9621
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7195 - loss: 89.3751
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7081 - loss: 99.3715
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7089 - loss: 184.6359
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6931 - loss: 110.5509
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6797 - loss: 338.1911
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7547 - loss: 147.0445
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7508 - loss: 30.8146
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7451 - loss: 21.2064
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7213 - loss: 146.2676
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7823 - loss: 15.3678
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7470 - loss: 52.3356
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7079 - loss: 54.8272
# Training history:
# Accuracy: [0.4353741407394409, 0.5340136289596558, 0.4931972920894623, 0.6054421663284302, 0.581632673740387, 0.6258503198623657, 0.557823121547699, 0.5170068144798279, 0.5340136289596558, 0.5748299360275269, 0.5748299360275269, 0.6258503198623657, 0.6326530575752258, 0.6326530575752258, 0.6326530575752258, 0.6666666865348816, 0.6428571343421936, 0.7210884094238281, 0.680272102355957, 0.6564626097679138, 0.680272102355957, 0.6326530575752258, 0.6972789168357849, 0.6598639488220215, 0.6904761791229248, 0.6972789168357849, 0.7176870703697205, 0.7074829936027527, 0.7142857313156128, 0.7210884094238281, 0.7482993006706238, 0.7448979616165161, 0.761904776096344, 0.7210884094238281, 0.704081654548645, 0.7108843326568604, 0.7517006993293762, 0.7312925457954407, 0.7074829936027527, 0.6768707633018494, 0.7108843326568604, 0.6836734414100647, 0.6870748400688171, 0.7517006993293762, 0.7414966225624084, 0.7346938848495483, 0.7414966225624084, 0.7823129296302795, 0.7414966225624084, 0.6904761791229248]
# Loss: [2520.93017578125, 2589.36279296875, 1681.5875244140625, 1347.680419921875, 1226.2718505859375, 802.8450317382812, 990.8101806640625, 1025.9384765625, 1812.822265625, 1106.5404052734375, 1078.6640625, 966.7759399414062, 869.7816162109375, 626.66259765625, 536.3412475585938, 534.5460815429688, 475.107421875, 505.27923583984375, 258.5061340332031, 363.7581787109375, 756.4680786132812, 873.8616333007812, 369.027099609375, 259.3064270019531, 169.62840270996094, 232.3846435546875, 160.08816528320312, 143.81626892089844, 167.86495971679688, 131.5410614013672, 86.61957550048828, 53.20438766479492, 56.612491607666016, 140.97872924804688, 121.82647705078125, 194.27369689941406, 113.3082504272461, 83.56328582763672, 102.2115707397461, 171.5449981689453, 127.58329010009766, 146.47567749023438, 342.75390625, 140.70199584960938, 36.819580078125, 30.565214157104492, 93.84742736816406, 20.9250545501709, 54.535945892333984, 50.847434997558594]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Test session accuracy: 0.5000
#
# Fold 8:
# Epoch 1/50
# ...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6177 - loss: 40.5954
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5969 - loss: 89.1500
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6351 - loss: 91.9398
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5857 - loss: 75.9539
# Training history:
# Accuracy: [0.5308219194412231, 0.6061643958091736, 0.534246563911438, 0.5821917653083801, 0.6061643958091736, 0.5582191944122314, 0.5787671208381653, 0.5616438388824463, 0.5890411138534546, 0.5993150472640991, 0.6232876777648926, 0.6164383292198181, 0.5958904027938843, 0.5993150472640991, 0.5753424763679504, 0.6232876777648926, 0.6027397513389587, 0.6095890402793884, 0.5650684833526611, 0.6130136847496033, 0.5993150472640991, 0.6027397513389587, 0.568493127822876, 0.6369863152503967, 0.534246563911438, 0.6061643958091736, 0.6095890402793884, 0.6027397513389587, 0.6164383292198181, 0.6130136847496033, 0.6301369667053223, 0.6369863152503967, 0.6335616707801819, 0.6301369667053223, 0.7020547986030579, 0.6746575236320496, 0.6267123222351074, 0.6541095972061157, 0.6541095972061157, 0.6712328791618347, 0.664383590221405, 0.6369863152503967, 0.6506849527359009, 0.6335616707801819, 0.6883561611175537, 0.6301369667053223, 0.6301369667053223, 0.6027397513389587, 0.6027397513389587, 0.6095890402793884]
# Loss: [3495.27587890625, 2453.933837890625, 3007.362060546875, 2349.8291015625, 2206.4296875, 2508.010009765625, 2344.27197265625, 2568.763671875, 1340.92578125, 1656.805908203125, 1153.9267578125, 830.72412109375, 570.2637329101562, 1075.4677734375, 664.0897216796875, 713.7742919921875, 482.5750732421875, 541.7515869140625, 516.7410888671875, 360.7503356933594, 750.8441772460938, 568.3999633789062, 401.5643005371094, 518.282958984375, 1238.6314697265625, 472.1196594238281, 587.8333740234375, 514.5698852539062, 373.2185974121094, 621.49853515625, 272.4286804199219, 317.35565185546875, 245.12066650390625, 165.90672302246094, 286.7167053222656, 280.0580749511719, 129.66729736328125, 101.78123474121094, 187.87559509277344, 185.28985595703125, 114.13121032714844, 111.09073638916016, 273.1988525390625, 141.8957061767578, 168.7515106201172, 36.68101501464844, 61.39081954956055, 62.93061828613281, 60.3313102722168, 57.564552307128906]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Test session accuracy: 0.4667
#
# Fold 9:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5368 - loss: 2505.4333
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4531 - loss: 2408.7397
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6351 - loss: 2271.9487
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5751 - loss: 1570.3534
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6259 - loss: 1206.2329
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5411 - loss: 1316.3129
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5944 - loss: 961.3020
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6003 - loss: 1019.0859
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5740 - loss: 930.0146
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5357 - loss: 494.1184
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5911 - loss: 479.6396
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 223ms/step - accuracy: 0.6018 - loss: 650.6586
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6250 - loss: 972.7094
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6193 - loss: 1547.4368
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6437 - loss: 519.1610
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6450 - loss: 493.9685
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6402 - loss: 414.0040
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7082 - loss: 180.5711
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6054 - loss: 794.0653
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6112 - loss: 415.3799
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5738 - loss: 496.1416
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5878 - loss: 269.5030
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6173 - loss: 1071.3041
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6340 - loss: 446.9747
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5680 - loss: 428.5039
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5674 - loss: 253.2330
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5800 - loss: 311.7264
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6107 - loss: 209.3785
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5803 - loss: 330.2046
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5861 - loss: 185.6650
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5853 - loss: 184.3952
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5732 - loss: 67.7975
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6566 - loss: 77.6003
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6001 - loss: 231.6415
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5604 - loss: 162.0267
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6153 - loss: 77.7227
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6001 - loss: 29.1723
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6063 - loss: 25.2561
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6671 - loss: 85.8638
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6297 - loss: 91.2418
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6421 - loss: 15.3241
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5724 - loss: 10.8616
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5578 - loss: 55.9653
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5854 - loss: 20.5009
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6061 - loss: 21.5992
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5600 - loss: 43.6634
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5579 - loss: 47.8374
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6534 - loss: 8.9229
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6129 - loss: 4.9907
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6016 - loss: 20.6882
# Training history:
# Accuracy: [0.5331010222434998, 0.4947735071182251, 0.588850200176239, 0.599303126335144, 0.592334508895874, 0.5156794190406799, 0.5714285969734192, 0.5435540080070496, 0.5609756112098694, 0.5331010222434998, 0.6341463327407837, 0.6167247295379639, 0.6132404208183289, 0.6341463327407837, 0.6202090382575989, 0.6620209217071533, 0.6202090382575989, 0.6794425249099731, 0.6341463327407837, 0.592334508895874, 0.5818815231323242, 0.599303126335144, 0.6167247295379639, 0.6167247295379639, 0.5818815231323242, 0.5609756112098694, 0.5400696992874146, 0.6097561120986938, 0.5818815231323242, 0.599303126335144, 0.595818817615509, 0.5540069937705994, 0.6202090382575989, 0.599303126335144, 0.5644599199295044, 0.6062718033790588, 0.599303126335144, 0.595818817615509, 0.6132404208183289, 0.6271777153015137, 0.595818817615509, 0.5818815231323242, 0.5644599199295044, 0.5540069937705994, 0.5749129056930542, 0.5644599199295044, 0.5853658318519592, 0.6236934065818787, 0.6271777153015137, 0.6271777153015137]
# Loss: [4003.505126953125, 2477.332275390625, 2366.93603515625, 1348.2572021484375, 1396.760009765625, 933.5104370117188, 1298.22119140625, 1007.3480224609375, 891.8516845703125, 741.3331909179688, 607.4453125, 838.3468627929688, 1130.654052734375, 1068.73876953125, 599.5128173828125, 372.8514404296875, 433.2206115722656, 238.2163543701172, 415.900146484375, 471.4482116699219, 454.8790283203125, 298.2501220703125, 1336.1090087890625, 586.4649658203125, 380.2465515136719, 309.08984375, 227.0381317138672, 237.02291870117188, 322.26922607421875, 204.88897705078125, 190.616943359375, 123.02139282226562, 91.4575424194336, 116.61264038085938, 99.95735168457031, 59.421165466308594, 40.077632904052734, 31.877344131469727, 95.5775375366211, 109.0667495727539, 26.084775924682617, 24.63033103942871, 33.68695831298828, 28.58787727355957, 21.655370712280273, 44.59395980834961, 50.135826110839844, 14.524992942810059, 4.377226829528809, 14.385297775268555]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Test session accuracy: 0.4000
#
# Fold 10:
# Epoch 1/50
# /home/bcml1/sigenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5411 - loss: 2304.1060
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5532 - loss: 2851.9841
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5730 - loss: 3118.9424
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4910 - loss: 2731.8108
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5223 - loss: 2430.6648
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5448 - loss: 2312.7131
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5979 - loss: 1897.7451
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5804 - loss: 2548.0063
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5633 - loss: 1716.0480
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5486 - loss: 1536.6951
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5717 - loss: 2445.4451
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6110 - loss: 1158.2684
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5652 - loss: 924.0433
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5978 - loss: 1270.6952
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6069 - loss: 494.0253
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5781 - loss: 1040.2642
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6078 - loss: 738.9980
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5905 - loss: 1035.1691
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6367 - loss: 1630.8495
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6103 - loss: 1337.7679
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6590 - loss: 731.2780
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6468 - loss: 1262.3580
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6419 - loss: 428.7600
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6156 - loss: 330.5739
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5945 - loss: 500.3540
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6608 - loss: 653.6999
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6373 - loss: 575.6147
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5644 - loss: 444.0461
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6154 - loss: 1161.8276
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5741 - loss: 718.8709
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6581 - loss: 443.9492
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5688 - loss: 432.4030
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5827 - loss: 659.2625
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6197 - loss: 428.0122
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6426 - loss: 421.1318
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6532 - loss: 220.1516
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6494 - loss: 174.6696
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 310ms/step - accuracy: 0.6227 - loss: 451.1078
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6609 - loss: 276.3666
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6476 - loss: 118.6665
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6906 - loss: 312.0623
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7102 - loss: 293.8868
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6165 - loss: 320.3748
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6628 - loss: 149.4310
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6183 - loss: 689.1559
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5883 - loss: 483.1897
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6747 - loss: 301.5499
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6209 - loss: 274.9474
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6013 - loss: 316.3199
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6294 - loss: 433.4679
# Training history:
# Accuracy: [0.5363321900367737, 0.5259515643119812, 0.5605536103248596, 0.5017300844192505, 0.49480968713760376, 0.5536332130432129, 0.5778546929359436, 0.5847750902175903, 0.5536332130432129, 0.5501729846000671, 0.5709342360496521, 0.6297577619552612, 0.5951557159423828, 0.5986159443855286, 0.6228373646736145, 0.5916954874992371, 0.5986159443855286, 0.5951557159423828, 0.6262975931167603, 0.6089965105056763, 0.6401383876800537, 0.6401383876800537, 0.633217990398407, 0.6366782188415527, 0.5986159443855286, 0.6366782188415527, 0.633217990398407, 0.5674740672111511, 0.6055363416671753, 0.5743944644927979, 0.6539792418479919, 0.5813148617744446, 0.5709342360496521, 0.6193771362304688, 0.6262975931167603, 0.6608996391296387, 0.6470588445663452, 0.6678200960159302, 0.6539792418479919, 0.6678200960159302, 0.6643598675727844, 0.6955017447471619, 0.6401383876800537, 0.6608996391296387, 0.6159169673919678, 0.6089965105056763, 0.6608996391296387, 0.612456738948822, 0.5813148617744446, 0.6159169673919678]
# Loss: [2271.990966796875, 2928.978271484375, 3734.8212890625, 2820.0380859375, 2519.531982421875, 1957.912353515625, 2854.31640625, 2979.18603515625, 1704.8792724609375, 1511.515869140625, 1808.65478515625, 1049.1112060546875, 797.065185546875, 1272.866943359375, 532.7968139648438, 1129.25927734375, 724.0376586914062, 1137.3956298828125, 934.0459594726562, 1205.191650390625, 769.4332885742188, 832.1869506835938, 511.99444580078125, 310.650146484375, 368.75494384765625, 565.9356689453125, 503.3685607910156, 695.8629150390625, 1135.545166015625, 952.0449829101562, 465.48291015625, 535.5476684570312, 621.1669311523438, 441.4272766113281, 411.3907470703125, 312.1943664550781, 201.78163146972656, 351.6103210449219, 272.4930114746094, 183.80426025390625, 324.7806701660156, 194.97848510742188, 251.2744140625, 173.02398681640625, 1013.5745239257812, 757.1917114257812, 249.01675415039062, 362.2382507324219, 394.4014892578125, 472.0138854980469]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Test session accuracy: 0.5455
# Mean accuracy across sessions: 0.5131
#
# Evaluation results have been saved to 'cnn_model1_evaluation_results.txt'.
